# %%
# Library Install
# !pip install nltk
import nltk
# !pip install numpy
import numpy as np
from string import punctuation
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from operator import itemgetter

# %% [markdown]
# # Question 1
# ### 1.	Compare your given name with your nickname (if you don’t have a nickname, invent one for this assignment) by answering the following questions:
# * What is the edit distance between your nickname and your given name?
# * What is the percentage string match between your nickname and your given name?
# Show your work for both calculations.

# %%
# My Name
name = 'Paul Huggins'

# My Nickname
nickname = 'Huggy Bear'

# Edit Distance
EditDistance = (name,nickname,nltk.edit_distance(name,nickname))
print(EditDistance)
print('Transforming ' + name + ' to ' + nickname + ' requires at least 11 steps')

# Clean Linebreaks
print(' ')
print(' ')
print(' ')

# Percentage Match
PercentageMatch = (name,nickname,(len(set(name).intersection(nickname)) / (len(name))) * 100)
print(PercentageMatch)
print(name + ' and ' + nickname + ' have a 41.67% percentage match')
# Out:
# ('Paul Huggins', 'Huggy Bear', 11)
# Transforming Paul Huggins to Huggy Bear requires at least 11 steps
#
#
#
# ('Paul Huggins', 'Huggy Bear', 41.66666666666667)
# Paul Huggins and Huggy Bear have a 41.67% percentage match

# %% [markdown]
# # Question 2
# ### 1.	Find a friend (or family member or classmate) who you know has read a certain book. Without your friend knowing, copy the first two sentences of that book. Now rewrite the words from those sentences, excluding stop words. Now tell your friend to guess which book the words are from by reading them just that list of words. Did you friend correctly guess the book on the first try? What did he or she guess? Explain why you think you friend either was or was not able to guess the book from hearing the list of words.

# %%
JungleBookPre = "It was seven o’clock of a very warm evening in the Seeonee hills when Father Wolf woke up from his day’s rest, scratched himself, yawned, and spread out his paws one after the other to get rid of the sleepy feeling in their tips. Mother Wolf lay with her big gray nose dropped across her four tumbling, squealing cubs, and the moon shone into the mouth of the cave where they all lived. “Augrh!” said Father Wolf. “It is time to hunt again.” He was going to spring down hill when a little shadow with a bushy tail crossed the threshold and whined: “Good luck go with you, O Chief of the Wolves. And good luck and strong white teeth go with noble children that they may never forget the hungry in this world.”"
print(JungleBookPre)

nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(JungleBookPre) 
JungleBookPost = [w for w in word_tokens if not w in stop_words] 
JungleBookPost = [] 
for w in word_tokens: 
    if w not in stop_words: 
        JungleBookPost.append(w) 
JungleBookPost = ' '.join(JungleBookPost)
print("-----------------------------------------------------")
print(JungleBookPost)
# Out:
# It was seven o’clock of a very warm evening in the Seeonee hills when Father Wolf woke up from his day’s rest, scratched himself, yawned, and spread out his paws one after the other to get rid of the sleepy feeling in their tips. Mother Wolf lay with her big gray nose dropped across her four tumbling, squealing cubs, and the moon shone into the mouth of the cave where they all lived. “Augrh!” said Father Wolf. “It is time to hunt again.” He was going to spring down hill when a little shadow with a bushy tail crossed the threshold and whined: “Good luck go with you, O Chief of the Wolves. And good luck and strong white teeth go with noble children that they may never forget the hungry in this world.”
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %% [markdown]
# #### My kids were still able to clearly able to distinguish that it was the same book after the Seeonee Hills words. There are a couple of factors involved here. Seeonee Hills is a place only attributed to the Jungle book and my kids only have a small library of books that they know and are reading.

# %% [markdown]
# # Question 3
# ### 1.	Run one of the stemmers available in Python. Run the same two sentences from question 2 above through the stemmer and show the results. How many of the outputted stems are valid morphological roots of the corresponding words? Express this answer as a percentage.

# %%
# importing modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()

JungleBookPreStem = word_tokenize(JungleBookPre)
for w in JungleBookPreStem:
    print(w, " : ", ps.stem(w))

JungleBookPostStem = word_tokenize(JungleBookPost)
for w in JungleBookPostStem:
    print(w, " : ", ps.stem(w))
# Out:
# It  :  it
# was  :  wa
# seven  :  seven
# o  :  o
# ’  :  ’
# clock  :  clock
# of  :  of
# a  :  a
# very  :  veri
# warm  :  warm
# evening  :  even
# in  :  in
# the  :  the
# Seeonee  :  seeone
# hills  :  hill
# when  :  when
# Father  :  father
# Wolf  :  wolf
# woke  :  woke
# up  :  up
# from  :  from
# his  :  hi
# day  :  day
# ’  :  ’
# s  :  s
# rest  :  rest
# ,  :  ,
# scratched  :  scratch
# himself  :  himself
# ,  :  ,
# yawned  :  yawn
# ,  :  ,
# and  :  and
# spread  :  spread
# out  :  out
# his  :  hi
# paws  :  paw
# one  :  one
# after  :  after
# the  :  the
# other  :  other
# to  :  to
# get  :  get
# rid  :  rid
# of  :  of
# the  :  the
# sleepy  :  sleepi
# feeling  :  feel
# in  :  in
# their  :  their
# tips  :  tip
# .  :  .
# Mother  :  mother
# Wolf  :  wolf
# lay  :  lay
# with  :  with
# her  :  her
# big  :  big
# gray  :  gray
# nose  :  nose
# dropped  :  drop
# across  :  across
# her  :  her
# four  :  four
# tumbling  :  tumbl
# ,  :  ,
# ...

# %% [markdown]
# ##### From the 1st couple of sentences from the Jungle Book pre removal of stop words... 8 did NOT match their stem (excluding punctuation). Therefore (149/157)*100 = 95% match
#
# ##### From the 1st couple of sentences from the Jungle Book post removal of stop words... 7 did NOT match their stem (excluding punctuation). Therefore (93/100)*100 = 93% match
